# %% [markdown]
# # Практика 4. Зависимость событий. Теорема Байеса.

# %% [markdown]
# ![title](mem31.jpg)

# %% [markdown]
# ## Видео
# [Условная вероятность](https://stepik.org/lesson/48662/step/1)
#
# [Теорема Байеса, независимые события](https://stepik.org/lesson/48663/step/1)

# %% [markdown]
# ## Теория
#
# [Условная вероятность](https://nsu.ru/mmf/tvims/chernova/tv/lec/node12.html#SECTION000510)
#
# [Независимость](https://nsu.ru/mmf/tvims/chernova/tv/lec/node13.html)
#
# [Формула полной вероятности](https://nsu.ru/mmf/tvims/chernova/tv/lec/node14.html)
#
# [Формула Байеса](https://nsu.ru/mmf/tvims/chernova/tv/lec/node15.html)

# %% [markdown]
# ## Определения

# %% [markdown]
# **Несовместные события**
# $$P(AB) = 0$$

# %% [markdown]
# **Независимые события**
# $$P(AB) = P(A)P(B)$$
#
# (Вообще говоря, привычная "независимость" и математическая "независисмость" - не одно и то же)

# %% [markdown]
# **Совместная независимость**
#
# $$P(ABC) = P(A)P(B)P(C)$$

# %% [markdown]
# **Попарная независимость A, B, C**
# $$P(AB) = P(A)P(B)$$ $$P(BC) = P(B)P(C)$$$$P(CA) = P(C)P(A)$$

# %% [markdown]
# **Формула Байеса**
# $$P(A|B) = \frac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# ![title](mem32.png)

# %% [markdown]
# ## Задачи на пару

# %% [markdown]
# **1.** Бросили две шестигранные игральные кости. Какова вероятность,
# что на первой выпадет шестерка, если:
# * на второй выпала единица.
# * сумма выпавших чисел семь.
# * сумма выпавших чисел девять.
# * разность выпавших чисел четыре.

# %% [markdown]
# **2.** В средневековой деревне болеет поголовье скота. Оцените вероятность того, что в этой деревне живет ведьма. Если в деревне есть ведьма, то скот болен с вероятностью $0.75$. Скот может заболеть в деревне без ведьмы с вероятностью $0.25$. А вероятность, что в этой деревне живет ведьма равна $0.001$.

# %% [markdown]
# **3.** Дано натуральное число $4 \le n \le 48$. Из тщательно перемешанной колоды в $52$ карты одновременно были взяты $n$ карт. На одну из этих $n$ карт посмотрели, она оказалась тузом. После этого она возвращается в набор взятых карт и эти $n$ карт перемешиваются. После этого из них выбирается одна карта и открывается. Найдите вероятность того, что открытая карта является тузом.

# %% [markdown]
# **4.** Существуют ли такие собития A, B, С, что:
#
# * A и B независимы, B и C независимы, но зависимы A и C;
#
# * A и B зависимы, B и C зависимы, но независимы A и C?

# %% [markdown]
# **5.**
# Рассмотрим следующую вероятностную модель. Студент на семинаре отвечает плохо (C = 1) или хорошо (C = 0) в зависимости от наличия/отсутствия депрессии (Д = 1 или Д = 0) и от участия в вечеринке накануне (В = 1 или В = 0). Участие в вечеринке также может приводить к тому, что у студента болит голова (Г = 1), а плохой ответ на семинаре влечёт недовольство преподавателя (П = 1).
#
# Известно, что
# * P(В=1) = 0.2
# * P(Д=1) = 0.4
#
# | P(С=1 при В,Д))| В   | Д   |
# |------------|-----|-----|
# |   0.9999   |  1  |  1  |
# |     0.9    |  1  |  0  |
# |     0.9    |  0  |  1  |
# |    0.01    |  0  |  0  |
#
# | P(Г=1 при В)| В   |
# |----------|-----|
# |   0.9   |  1  |
# |   0.2   |  0  |
#
#
# | P(П=1 при С)| С   |
# |----------|-----|
# |   0.95  |  1  |
# |   0.5   |  0  |
#
#
# Требуется найти
# * P(В=1|Г=1)
# * P(В=1|П=1)
# * P(В=1|П=1, Г=1)
#
# Связи событий:
#
# ![title](bayes.png)

# %% [markdown]
# ## ДЗ

# %% [markdown]
# **1. (1 балл)** В результате медицинского обследования один из тестов выявил у человека серьезное заболевание. Данный тест имеет высокую точность 99% (вероятность позитивного ответа при наличии заболевания 99%, вероятность отрицательного ответа при отсутствии заболевания также 99%). Однако, выявленное заболевания является достаточно редким и встречается только у одного человека на $10000$. Вычислить вероятность того, что у обследуемого человека действительно есть выявленное заболевание.

# %% [markdown]
# **2. (1 балл)** Показать, что
# $P(A|B) =P(A|BC)P(C|B)+P(A|B\overline{C})P(\overline{C}|B).$

# %% [markdown]
# **3. (1 балл)** Есть 4 кубика. На трех из них окрашена белым половина граней, а на четвертом кубике всего одна грань из шести белая. Наудачу выбранный кубик подбрасывается семь раз. Найти вероятность того, что был выбран четвертый кубик, если при семи подбрасываниях белая грань выпала ровно один раз.

# %% [markdown]
# **4. (1 балл)** $n$ шаров, среди которых белых ровно $k$, случайным образом распределили по трем ящикам (каждый шар с равной вероятностью мог попасть в каждый ящик). Оказалось, что в первом ящике все шары белые. Какова вероятность, что во втором ящике нет ни одного белого шара?

# %% [markdown]
# **5. (1 балл)** В суде рассматривает дело об убийстве жены О. Джей Симпсона. Прокурор указал, что О. Джей Симпсон уже бил жену в прошлом. Адвокат ответил: "Убивают только одну из 2500 женщин, подвергающихся семейному насилию, так что это вообще нерелевантно". Суд согласился с адвокатом, верно ли это рассуждение?

# %% [markdown]
# **6. (1 балл)** Необходимо построить N-Gram Language Model и обучить на основе старой доброй "Войне и мире" (Хмм.. Или как-то по другому тут склоняется).
#
# На вход модели подается текст "Война и мир". Вам необходимо его токенизировать(см. модуль в питоне nltk.tokenize) и посчитать следующие вероятности:
#
# $$ P(w | prefix) = { Count(prefix, w) \over \sum_{\hat w} Count(prefix, \hat w) } $$
# $$prefix = (w_1, w_2, ..., w_{n-1})$$

# %%
import typing


class NGramLanguageModel:    
    def __init__(self, text: str, n: int):
        pass
        
    def get_next_tokens_probabilies(
        self, 
        prefix:typing.List[str]
    ) -> typing.Dict[str, float]:
        pass

# %% [markdown]
# ### Мотивация
#
# Формула Байеса нашла огромное применение в машинном обучении.
#
# [Реализация наивного Байесовского классификатора](https://habr.com/ru/post/120194/)
#
# [Нейронки + Теорема Байеса](https://www.youtube.com/watch?v=kFe5zSkro0E)
#
# [Хардкор. Курс ВШЭ: Байесовские методы в машинном обучении](https://www.youtube.com/playlist?list=PLEqoHzpnmTfCiJpMPccTWXD9DB4ERQkyw)

# %% [markdown]
# ## Гробы

# %% [markdown]
# **1. (1 балл)** Найти вероятность того, что станок, работающий в момент $t_0$, не остановится до момента $t_0+t$, если известно, что эта вероятность зависит только от величины промежутка времени $(t_0,t_0+t)$ и вероятность того, что станок остановится за промежуток времени $\Delta t$, пропорциональна $\Delta t$ с точностью до бесконечно малых высших порядков относительно $\Delta t$.

# %% [markdown]
# **2. (1 балл)** С утра студент Иван не мог решить, идти ли ему на пары или сладко спать до двух. Тогда он решил подбрасывать монетку, пока впервые не выпадет орел. Иван решил, что если это случится на четном броске, то он пойдет в университет, иначе продолжит спать. Известно, что у Ивана две монетки: одна правильная, другая падает орлом вверх в трех случаях из четырех. Естественно, студенту хочется воспользоваться второй (кстати, почему?), но как их различить? Иван решил подбросить обе монетки по разу и взять любую из тех, на которых выпадет наибольшее количество орлов. С какой все-таки вероятностью Иван пойдет на пары?

# %% [markdown]
# **3. (1 балл)**
# Последовательность событий $\{A_n\}$ такова, что при любом натуральном $n$ выполняется:
# * $P(A_{n+1}|A_n)=\frac{1}{2}$.
# * $\forall m<n: P(A_n|A_m)=\frac{1}{2}$.
# Найдите точную верхнюю грань множества вероятностей пересечений бесконечных подпоследовательностей данной последовательности.

# %% [markdown]
# **4. (0.5 баллов)** В автобусе $n$ мест, и все билеты проданы $n$ пассажирам. Первым в автобус заходит Рассеянный Учёный и, не посмотрев на билет, занимает первое попавшееся место. Далее пассажиры входят по одному. Если вошедший видит, что его место свободно, он занимает свое место. Если же место занято, то вошедший занимает первое попавшееся свободное место. Найдите вероятность того, что пассажир, вошедший последним, займет место согласно своему билету.

# %% [markdown]
# **5. (0.5 баллов)**
# * Существуют ли такие совместно зависимые события $A_1, \ldots, A_n$, что любые $n-1$ из них совместно независимы?
# * Может ли быть, что любые $k-1$ из $A_1, \ldots, A_n$ совместно независимы, но любые $k$ совместно зависимы?

# %% [markdown]
# **6. (0.5 баллов)**
# Однажды Петр нашел абсолютно симметричную монетку. Он подбросил ее один раз, после чего делал броски до тех пор, пока суммарные количества выпавших орлов и решек не сравнялись. Оказалось, что всего Петр подбросил монетку $2n$ раз. Найдите вероятность того, что впервые орел был выброшен на четвертом броске.
