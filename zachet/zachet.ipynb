# %% [markdown]
# # Зачет

# %% [markdown]
# ## на 3

# %% [markdown]
# ### Котельникова
#
# Пусть $p\in(0,1)$. Случайная величина $\xi$ принимает натуральные значения с вероятностями $P(\xi=k)=-\dfrac {1}{\ln(1-p)}\cdot\dfrac{p^k}{k}$ Найдите $\mathbb E\xi$ и $\mathbb D\xi$.

# %% [markdown]
# ### Черенцов
# Правильный игральный кубик подбрасывается до тех пор, пока не выпадет шестерка. Случайная величина $\xi$ — количество сделанных бросков, а случайная величина $\eta$ — количество троек, которое выпало в процессе. Найдите $\mathbb{E}(\eta|\xi=n)$.

# %% [markdown]
# ### Занин
#
# 1. С помощью неравенства Чебышёва оцените вероятность того, что в результате подбрасывания игральной кости в течение $400$ раз относительная частота появления на верхней грани шестерки отклонится от вероятности этого события (по абсолютной величине) не более чем на $0,03$.
# 2. В круге радиуса $R$ с центром в начале координат наугад выбирается точка. Случайная величина $\xi$ — абсцисса выбранной точки. Найдите плотность распределения $\xi$.

# %% [markdown]
# ### Мухаметдинова
#
# Золушке поручено разобрать мешок фасоли, в котором находится $n$ белых фасолин и $m$ коричневых. Некоторые из фасолин проросли. Количество проросших белых фасолин имеет биномиальное распределение с параметрами $n$ и $p\in(0,1)$, а количество проросших коричневых фасолин имеет биномиальное распределение с параметрами $m$ и $p$. Помогите Золушке найти распределение проросших фасолин в мешке. В качестве ответа приведите вероятность того, что в мешке ровно $k$ (конечно же, $k < m+n$) проросших фасолин.
#
# Указание: воспользуйтесь характеристическими функциями

# %% [markdown]
# ### Аникина
# 1. В одной команде Контура очень любят сотрудников, поэтому решили, устраивать всем выходной, когда у кого-нибудь из людей день рождения. Однако в этом случае они не могут набирать много людей, так как с большой вероятностью работа будет не выполнена. Работник рождается в любой из дней в году (365 дней) с равной вероятностью. Сколько людей должно быть в команде, чтобы ее эффективность была наибольшей? (Эффективность считаем как кол-во сотрудников * кол-во рабочих дней). Считаем, что выходных и так много, поэтому суббота и воскресенье - изначально рабочие дни.
# 2.Число $\xi$ выбирается случайным образом из множества целых чисел $\{1,2,3,4\}$. Затем из того же множества выбирается число $\eta$, большее $\xi$ или равное ему. Найдите $\mathbb E\eta$, $\mathbb D\eta$ и $\mathop{\mathrm{cov}}(\xi,\eta)$.
# 3. Время исправной работы прибора в днях — равномерно распределенная на $\{0,1,2,\dots,N\}$ случайная величина. Прибор уже проработал $t<N$ дней. Найдите математическое ожидание времени работы прибора.

# %% [markdown]
# ----------

# %% [markdown]
# ## На 4

# %% [markdown]
# ### Лебедев
#
# Завод произвел $n$ приборов, каждый из которых неисправен с вероятностью $p\in(0,1)$
# и неисправности приборов не зависят друг от друга.
# К каждому прибору применяется тест, который при наличии неисправности обнаруживает ее с вероятностью
# $q\in(0,1)$ Пусть $\xi$ — количество неисправных приборов, а $\eta$ — количество приборов, не прошедших тест.
# Найдите $\mathbb{E}(\xi|\eta)$. Это математическое ожидание зависит от $n, p, q$ и $\eta$.

# %% [markdown]
# ### Пережогин
#
# Рассмотрим схему Бернулли с вероятностью успеха $p\in(0,1)$. Случайная величина $\xi_n$ - обозначает число испытаний до достижения серии из n последовательных успехов. Найдите $\mathbb{E}\xi_n$
#
# Указание. С помощью формулы $\mathbb{E}\xi_n=\mathbb{E}\big(\mathbb{E}(\xi_n\,|\,\xi_{n-1})\big)$ выразите $\mathbb{E}\xi_n$ через $\mathbb{E}\xi_{n-1}$

# %% [markdown]
# ### Финогенов
#
# Дано $p\in(0,1)$. Пусть $\xi_1, \xi_2, \ldots, \xi_n$ — независимые бернуллиевские случайные величины с вероятностью успеха p и ${\zeta=\xi_1+\xi_2+\ldots+\xi_n}$ Случайная величина $\eta$ задается формулой ${\eta=\xi_1+\xi_2+\ldots+\xi_\zeta}$. Найдите $\mathbb{E}\eta$.

# %% [markdown]
# ### Трифочкин
#
# https://codeforces.com/problemset/problem/107/E
