# %% [markdown]
# # Практика 8. Абсолютно непрерывные случайные величины. Плотность. Формула замены переменной.

# %% [markdown]
# ## Теория
#
# [Случайные величины](https://nsu.ru/mmf/tvims/chernova/tv/lec/node23.html#SECTION000710)
#
# [Распределения случайных величин](https://nsu.ru/mmf/tvims/chernova/tv/lec/node24.html#SECTION000720)
#
# [Функция распределения](https://nsu.ru/mmf/tvims/chernova/tv/lec/node25.html#SECTION000730)
#
# [Примеры непрерывных распределений](https://nsu.ru/mmf/tvims/chernova/tv/lec/node27.html#SECTION000750)

# %% [markdown]
# ## Видео

# %% [markdown]
# [Непрерывные случайные величины](https://stepik.org/lesson/48684/step/1?unit=26454)

# %% [markdown]
# ## Задачи на пару

# %% [markdown]
# **1.**
# Случайная величина $\xi$ имеет функцию распределения $F_{\xi}$, определенную равенством
# $$F_\xi(x) =\left\{
# 	\begin{array}{cc}
# 	4^{x}, & x\leq 0 \\
# 	1, & x>0
# 	\end{array}\right.$$
# Найдите вероятности
# $P(\xi \geq -2)$ и $P(-1 < \xi < 0)$. Найдите плотность $\rho_{\xi}(x)$.
#
# **2.** Случайная величина $\xi$ имеет непрерывную функцию распределения $F_{\xi}(x)$.
# Найдите функцию распределения случайной величины $\eta=3-2\xi$.
#
# **3.** 2 лыжника условились о встрече в промежуток времени $[0,1]$. Момент прихода на встречу каждым выбирается равновероятно. Первый лыжник пришел в момент времени $t_1$, второй лыжник в $t_2$. Пусть $\theta = |t_1 - t_2|$. Найдите:
# - функцию распределения $F_{\theta}(x)$
# - плотность вероятности $\rho_{\theta}(x)$
# - матожидание $E\theta$
# - дисперсию $D\theta$
#
# **4.**
# Функция распределения случайной величины $\xi$ имеет вид $F_{\xi}(x)=a + b*arctg(x)$.
# Найдите:
# * параметры $a$ и $b$
# * плотность вероятности.

# %% [markdown]
# **5.**
# Дана плотность вероятности $\rho_{\xi} = \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{(x-\mu)^2}{2\sigma^2}}$.
# Доказать что:
# * $E_{\xi}= \mu$
# * $\sigma_{\xi}= \sigma$

# %% [markdown]
# ## ДЗ

# %% [markdown]
# **1.**
# В квадрате $[0,1]^2$ наугад выбирается точка $\omega=(\omega_1,\omega_2)$. Случайная величина $\xi$ задается равенством $\xi(\omega)=\omega_1+\omega_2$. Найдите функцию распределения $F_{\xi}(x)$.
#
# **2.**
# Случайная величина $\xi$ имеет непрерывную функцию распределения $F_{\xi}(x)$.
# Найдите функцию распределения случайной величины $\eta=1-3\xi^2$.
#
# **3.**Плотность распределения случайной величины $\xi$ задана формулой
# 	$$f_\xi(x) =\left\{
# 	\begin{array}{cc}
# 	Cx^{-3/2}, & x\geq 1 \\
# 	0, & x<1
# 	\end{array}\right.$$
# Найти:
# * постоянную $C$;
# * плотность распределения $\eta=1/\xi$
# * $P\{0,1<\eta<0,2\}$.
#
# **4.** Случайная величина $\xi$ имеет распределение Коши с плотностью $\rho_{\xi}(x)=\frac{1}{\pi(1+x^2)}$.
# Найдите плотность и функцию распределения случайной величины $\eta = \frac{1}{1+\xi^2}$.

# %% [markdown]
# ## Гробы

# %% [markdown]
# **1.** (Яндекс) Паша входит на станцию метро с кольцевым маршрутом. Ему нужно добраться до диаметрально противоположной станции, поэтому ему не важно на какой поезд садиться. Поезда приходят на станцию с равным интервалом в 1 час в каждую сторону. С какой вероятностью Паша сядет на один поезд или на другой поезд? (Можно считать, что поезда точки во времени и Паша садится в первую прибывшую точку на станцию)
