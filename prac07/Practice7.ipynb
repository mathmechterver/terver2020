# %% [markdown]
# # Практика 7. Дисперсия. Ковариация.

# %% [markdown]
# ## Теория
#
# [Ковариация](https://nsu.ru/mmf/tvims/chernova/tv/lec/node48.html#SECTION0001110)
#
# [Корреляция](https://nsu.ru/mmf/tvims/chernova/tv/lec/node49.html#SECTION0001120)

# %% [markdown]
# ## Видео
#
# [Дисперсия, ковариация, корреляция](https://stepik.org/lesson/48669/step/2?unit=26440)

# %% [markdown]
# ## Линейность математического ожидания

# %% [markdown]
# 1. $E(a\xi) = \sum(a\xi_i)P(\xi = \xi_i) = a \sum(\xi_i)P(\xi = \xi_i) = aE\xi$

# %% [markdown]
# 2. $E(\xi + \eta)
# =\\ \sum\limits_{x \in X_{\xi + \eta}}xP(\xi + \eta = x)
# =\\ \sum\limits_{s \in X_{\xi}, t \in X_{\eta}} (s+t) P(\xi =s, \eta = t)
# =\\ \sum\limits_{s \in X_{\xi}, t \in X_{\eta}} s P(\xi =s, \eta = t) + \sum\limits_{s \in X_{\xi}, t \in X_{\eta}} t P(\xi =s, \eta = t)
# =\\ \sum\limits_{s \in X_{\xi}, t \in X_{\eta}} s P(\eta = t |\xi =s)P(\xi =s) + \sum\limits_{s \in X_{\xi}, t \in X_{\eta}} t P(\xi =s| \eta = t)P(\eta = t)
# =\\ {\sum\limits_{s \in X_{\xi}} \sum\limits_{t \in X_{\eta}}}  s P(\eta = t |\xi =s)P(\xi =s) + {\sum\limits_{s \in X_{\xi}} \sum\limits_{t \in X_{\eta}}} t P(\xi =s| \eta = t)P(\eta = t)
# =\\{\sum\limits_{s \in X_{\xi}}}  sP(\xi =s)(\sum\limits_{t \in X_{\eta}}P(\eta = t |\xi =s)) + {\sum\limits_{t \in X_{\eta}}} t P(\eta = t)(\sum\limits_{s \in X_{\xi}} P(\xi =s| \eta = t))
# =\\{\sum\limits_{s \in X_{\xi}}}  sP(\xi =s) + {\sum\limits_{t \in X_{\eta}}} t P(\eta = t) =\\ E \xi + E \eta$

# %% [markdown]
# ## Задачи на пару

# %% [markdown]
# **1.** Пусть $\xi$ и $\eta$ - независимые случайные величины. Доказать, что $E\xi\eta = E \xi E \eta$.
#
# **2.**
# В каком случае $D(\xi + \mu) = D\xi + D\mu$? А в каком не равно? На какую величину они будут отличаться в общем случае?
#
# **3.**
# Докажите свойства ковариаций
# - $cov(\xi, \mu) = cov(\mu, \xi)$
# - $cov(\alpha\xi, \mu) = \alpha cov(\xi, \mu)$
# - $cov(\xi_1 + \xi_2, \mu) = cov(\xi_1, \mu) + cov(\xi_2, \mu)$
#
# **4.**
# Двумерное распределение пары целочисленных случайных величин $\xi$ и $\eta$ задаётся с помощью таблицы, где в пересечении столбца $\xi = i$ и строки $\eta = j$ находится вероятность $P\lbrace{\xi = i, \eta = j\rbrace}$.
#
# |$\xi$ & $\eta$     |$\xi$ $=$ $-1$    |$\xi$ $=$ $0$|$\xi$ $=$ $1$|
# |-------------------|------------------|---------|---------|
# |  $\eta$ $=$ $-1$  |$\frac{1}{8}$    |$\frac{1}{12}$ |$\frac{7}{24}$|
# |  $\eta$ $=$ $1$  |$\frac{5}{24}$    |$\frac{1}{6}$ |$\frac{1}{8}$|
#
# Найти:
#
# - Дисперсию: $D(\xi), D(\eta)$,
# - Ковариацию:  $Cov(\xi, \eta) $,
# - Корреляцию: $\rho$ $(\xi, \eta)$
#
# **5.**
# Пусть в урне содержится $N$ шаров, из них $a$ белых, $b$ черных и $c$ красных, $a + b + c = N$. Вынимается $n$ шаров, и пусть среди них $\xi$ белых и $\eta$ черных.
#
# - Показать, что если совершаемый выбор –– это «выбор
# с возвращением», то $Cov(\xi, \eta) = -npq$, где $p = \frac{a}{N}$ и $q = \frac{b}{N}$. Если же производится «выбор без возвращения», то $Cov(\xi, \eta) = -npq\frac{N - n}{N - 1}$.
#
# - Показать также, что в обоих случаях корреляция $\rho(\xi, \eta) = -\sqrt{\frac{pq}{(1 - p)(1 - q)}}$.

# %% [markdown]
# ## Домашка

# %% [markdown]
# **1. (1.5 балл)**
# Найти коэффициент корреляции между $\xi$ и $\xi^2$, если:
#
# - $P\lbrace{\xi = 0\rbrace} = 1/3, P\lbrace{\xi = 1\rbrace} = 1/3, P\lbrace{\xi = -1\rbrace} = 1/3$ - данный пример показывает, что существуют зависимые случайные величины, для которых $D(\xi + \mu) = D\xi + D\mu$ (см. задание 2 из классной работы)
#
#
# - $P\lbrace{\xi = 0\rbrace} = 1/3, P\lbrace{\xi = 1\rbrace} = 1/2, P\lbrace{\xi = -1\rbrace} = 1/6$;
# - $P\lbrace{\xi = -2\rbrace} = P\lbrace{\xi = -1\rbrace} = P\lbrace{\xi = 1\rbrace} = P\lbrace{\xi = 2\rbrace} = 1/4$.
#
# **2. (1 балл)**
# Найти коэффициент корреляции между числом ``единиц`` и числом ``шестёрок`` при $n$ бросаниях правильной игральной кости.
#
# **3. (2 балл)**
# Пусть $\xi_1, \xi_2, ... $ - независимые случайные величины, принимающие значения $1$ и $0$ с вероятностями $p$ и $1 - p$ соответственно. Найти среднее значение и дисперсию суммы $\zeta = \eta_1 + ... + \eta_n$, если:
# - $\eta_i = \xi_i \xi_{i + 1}$;
# - $\eta_i = \xi_i \xi_{i + 1} \xi_{i + 2}$;
# - Если $\eta_i$ задана правилом:
#     - $\eta_i = 0$, если $\xi_i + \xi_{i + 1}$ - чётное число,
#     - $\eta_i = 1$, иначе
#
# **4. (1.5 балл)**
# Случайные величины $\xi$ и $\eta$ независимы и имеют одинаковое распределение с математическим ожиданием $M$ и дисперсией $N$. Найдите коэффициент корреляции cлучайных величин $a\xi+b\eta$ и $a\xi−b\eta$ ($a$ и $b$ — вещественные числа).

# %% [markdown]
# # Гробы

# %% [markdown]
# **1. (2 балла)** Ваша хеш-функция переводит объект число от 1 до 10000 с равной вероятностью. У нас имеется 1000 объектов.
# * Какова вероятность того, что произойдет коллизия?
# * Найдите матожидание кол-ва коллизий?
# * Найдите матожидание кол-ва неиспользованных хешей.
#
# **2. (1 балл)** В Швейцарском Фейсбуке очень любят сотрудников, поэтому решили, устраивать всем выходной, когда у кого-нибудь из людей день рождение. Однако в этом случае они не могут набирать много людей, так как с большой вероятностью работа будет не выполнена. Работник рождается в любой из дней в году (365 дней) с равной веротяностью. Найдите наибольшее матожидание величины (кол-во сотрудников * кол-во рабочих дней).
#
# **3. (1 балл)** На день рождения Дианы мы принесли торт с N свечами. Когда мы пытаемся задуть свечи, мы точно задуваем одну свечу, а количество оставшихся гореть свечей распределено равновероятно. (от 0 до N-1). При следующем задуве ситуация аналогичная. Вопрос: найти матожидание числа задуваний, которое должна сделать Диана.
#
# **4. (1 балл)** У нас в хороводе стоит n куриц. В какой-то момент все курицы клюют одного из своих соседей слева или справа. Найти матожидние кол-ва куриц, которых не клюнули.
#
# **5. (1 балл)** Ребята на ЗМШ решили сыграть в игру: У нас есть 6 пустых стаканов пронумерованных от 1 до 6. Участник подбрасывает игральный кубик и получает число от 1 до 6. Если стакан под выпавшим номером пустой - то его заполняют Бэтменом, если стакан полный - то участник опустошает данный стакан. Если игрок попадает в ситуацию, когда все 6 стаканов заполнены, то он выпивает все 6 стаканов, его нарекают “Темным рыцарем” и игра заканчивается. Вопрос, найдите среднюю длительность данной игры (матожидание ходов), при условии, что все участники готовы сражаться до победного конца.
#
# **6. (1 балл)** (Точка) У нас есть случайная величина, которая выдает 0 и 1 с равными вероятностями. Как используя только такую случайную величину получить сл. величину, которая с равными вероятностями выдает 0, 1, 2?
#
#
# **7. (1 балл)** https://codeforces.com/problemset/problem/453/A
#
# **8. (1 балл)** https://codeforces.com/problemset/problem/621/C
#
# **9. (1 балл)** https://codeforces.com/problemset/problem/839/C
